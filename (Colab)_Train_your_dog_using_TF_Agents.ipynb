# %% [markdown]
# # Train your dog using TF-Agents

# %%
# !pip install tf-agents
# Out:
# Collecting tf-agents
#   Downloading https://files.pythonhosted.org/packages/7c/77/df0c0ca6f0b1a59b812d81d7737d8ea2a95d8716f9ffc1a68822531b78fb/tf_agents-0.6.0-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 13.4MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (1.18.5)
# Requirement already satisfied: cloudpickle==1.3 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (1.3.0)
# Requirement already satisfied: gin-config>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (0.4.0)
# Requirement already satisfied: tensorflow-probability>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (0.11.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (1.15.0)
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (0.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (1.12.1)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (3.12.4)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability>=0.11.0->tf-agents) (0.1.5)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability>=0.11.0->tf-agents) (0.3.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability>=0.11.0->tf-agents) (4.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.11.3->tf-agents) (50.3.2)
# Installing collected packages: tf-agents
# Successfully installed tf-agents-0.6.0

# %% [markdown]
# ### Imports

# %%
from enum import Enum
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tf_agents.environments import py_environment
from tf_agents.environments import tf_environment
from tf_agents.environments import tf_py_environment
from tf_agents.environments import utils
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as timeStep

from tf_agents.policies import random_tf_policy

from tf_agents.metrics import tf_py_metric
from tf_agents.metrics import tf_metrics
from tf_agents.metrics import py_metric
from tf_agents.drivers import py_driver
from tf_agents.drivers import dynamic_episode_driver

from tf_agents.agents.dqn import dqn_agent
from tf_agents.drivers import dynamic_step_driver
from tf_agents.networks import q_network
from tf_agents.replay_buffers import tf_uniform_replay_buffer

from tf_agents.policies import random_tf_policy
from tf_agents.trajectories import trajectory
from tf_agents.utils import common

from tf_agents.policies import policy_saver
# Out:
# WARNING:root:Argument blacklist is deprecated. Please use denylist.
# WARNING:root:Argument blacklist is deprecated. Please use denylist.

# %%
def column(matrix, i):
    return [row[i] for row in matrix]

# %% [markdown]
# ### Game Environment

# %%
class ActionResult(Enum):
    VALID_MOVE = 1
    ILLEGAL_MOVE = 2
    FOUND_BONE = 3
    FOUND_ROBOT = 4
    GAME_COMPLETE = 5

# %%
class DogAdventure():
    def __init__(self):
        self._state = np.zeros((36,),dtype=np.int32)
        self._robot_locations = [6,10,14,25,33]
        self._bone_locations = [5,7,9,16,19,26,30]
        self._state[self._robot_locations] = 2
        self._state[self._bone_locations] = 3
        self._state[0] = 1
        self._game_ended = False

    def reset(self):
        self._state = np.zeros((36,),dtype=np.int32)
        self._state[self._robot_locations] = 2
        self._state[self._bone_locations] = 3
        self._state[0] = 1
        self._game_ended = False

    def __is_spot_last(self, position):
        return position == 35

    def move_dog(self, current_position, next_position):

        if self.__is_spot_last(next_position):
            self._state[current_position] = 0
            self._state[next_position] = 1

            self._game_ended = True
            return ActionResult.GAME_COMPLETE

        if next_position < 0 or next_position > (len(self._state) - 1):
            self._game_ended = True
            return ActionResult.ILLEGAL_MOVE

        if self._state[next_position] == 2:
            self._game_ended = True
            return ActionResult.FOUND_ROBOT

        if self._state[next_position] == 3:
            self._state[current_position] = 0
            self._state[next_position] = 1
            return ActionResult.FOUND_BONE

        self._state[current_position] = 0
        self._state[next_position] = 1

        return ActionResult.VALID_MOVE

    def game_ended(self):
        return self._game_ended
  
    def game_state(self):
        return self._state

# %%
class DogAdventureEnvironment(py_environment.PyEnvironment):

    def __init__(self, game):
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(), dtype=np.int32, minimum=0, maximum=3, name='action')
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(36,), dtype=np.int32, minimum=0, maximum=3, name='observation')

        # 0=>Left, 1=>Right, 2=>Down, 3=>Up
        self._action_values = {0:-1,1:1,2:-6,3:6}
        self._game = game

    def action_spec(self):
        return self._action_spec

    def observation_spec(self):
        return self._observation_spec

    def _reset(self):
        self._game.reset()
        return timeStep.restart(self._game.game_state())
  
    def _step(self, action):    

        if self._game.game_ended():
            return self.reset()

        action = action.item()

        next_agent_position_direction = self._action_values.get(action)
        current_agent_position = np.where(self._game.game_state() == 1)[0].item()
        new_agent_position = current_agent_position + next_agent_position_direction

        response = self._game.move_dog(current_agent_position,new_agent_position)

        if response == ActionResult.GAME_COMPLETE:
            return timeStep.termination(self._game.game_state(), 10)

        elif response == ActionResult.ILLEGAL_MOVE:
            return timeStep.termination(self._game.game_state(), -0.3)

        elif response == ActionResult.FOUND_ROBOT:
            return timeStep.termination(self._game.game_state(), -0.3)

        elif response == ActionResult.FOUND_BONE:
            return timeStep.transition(self._game.game_state(), reward=1, discount=1.0)

        return timeStep.transition(self._game.game_state(), reward=-0.3, discount=1.0)

# %%
dogEnvironemt = DogAdventureEnvironment(DogAdventure())
utils.validate_py_environment(dogEnvironemt, episodes=5)

# %%
train_env = tf_py_environment.TFPyEnvironment(dogEnvironemt)
eval_env = tf_py_environment.TFPyEnvironment(dogEnvironemt)

# %% [markdown]
# ### DQN Setup

# %%
fc_layer_params = [32,64,128]

q_net = q_network.QNetwork(
            train_env.observation_spec(),
            train_env.action_spec(),
            fc_layer_params = fc_layer_params
        )

train_step = tf.Variable(0)
update_period = 4
optimizer = tf.keras.optimizers.Adam(lr=2.5e-4, epsilon=0.00001)

epsilon_fn = tf.keras.optimizers.schedules.PolynomialDecay(
                initial_learning_rate=1.0, 
                decay_steps=250000 // update_period,
                end_learning_rate=0.01)

agent = dqn_agent.DdqnAgent(
        train_env.time_step_spec(),
        train_env.action_spec(),
        q_network=q_net,
        optimizer=optimizer,
        target_update_period=2000,
        td_errors_loss_fn=tf.keras.losses.Huber(reduction="none"),
        gamma=0.99,
        train_step_counter=train_step,
        epsilon_greedy=lambda: epsilon_fn(train_step))

agent.initialize()

# %% [markdown]
# ### Replay Buffer Setup

# %%
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=1000000)

replay_buffer_observer = replay_buffer.add_batch

# %% [markdown]
# ### Metrics Setup

# %%
train_metrics = [tf_metrics.AverageReturnMetric(), tf_metrics.AverageEpisodeLengthMetric()]

# %% [markdown]
# ### Driver Setup

# %%
collect_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    agent.collect_policy,
    observers=[replay_buffer_observer] + train_metrics,
    num_steps=update_period)

# %% [markdown]
# ### Collect trajectories using Random Policy

# %%
class ShowProgress:
    def __init__(self, total):
        self.counter = 0
        self.total = total
    def __call__(self, trajectory):
        if not trajectory.is_boundary():
            self.counter += 1
        if self.counter % 100 == 0:
            print("\r{}/{}".format(self.counter, self.total), end="")

# %%
initial_collect_policy = random_tf_policy.RandomTFPolicy(train_env.time_step_spec(), train_env.action_spec())

init_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    initial_collect_policy,
    observers=[replay_buffer.add_batch, ShowProgress(20000)],
    num_steps=20000)

final_time_step, final_policy_state = init_driver.run()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_agents/drivers/dynamic_step_driver.py:203: calling while_loop_v2 (from tensorflow.python.ops.control_flow_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.while_loop(c, b, vars, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.while_loop(c, b, vars))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_agents/drivers/dynamic_step_driver.py:203: calling while_loop_v2 (from tensorflow.python.ops.control_flow_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.while_loop(c, b, vars, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.while_loop(c, b, vars))
# 20000/20000

# %% [markdown]
# ### Verify collected trajectories

# %%
trajectories, buffer_info = replay_buffer.get_next(sample_batch_size=2, num_steps=10)
# Out:
# WARNING:tensorflow:From <ipython-input-18-ab9318a97084>:1: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# WARNING:tensorflow:From <ipython-input-18-ab9318a97084>:1: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.

# %%
trajectories._fields
# Out:
# ('step_type',
#  'observation',
#  'action',
#  'policy_info',
#  'next_step_type',
#  'reward',
#  'discount')

# %%
time_steps, action_steps, next_time_steps = trajectory.to_transition(trajectories)
time_steps.observation.shape
# Out:
# TensorShape([2, 9, 36])

# %% [markdown]
# ### Create Dataset from Replay Buffer

# %%
dataset = replay_buffer.as_dataset(sample_batch_size=100, num_steps=2, num_parallel_calls=3).prefetch(3)

# %% [markdown]
# ### Run it under common function to make it faster

# %%
collect_driver.run = common.function(collect_driver.run)
agent.train = common.function(agent.train)

# %% [markdown]
# ### Train

# %%
all_train_loss = []
all_metrics = []

# %%
def train_agent(n_iterations):
    time_step = None
    policy_state = agent.collect_policy.get_initial_state(train_env.batch_size)
    iterator = iter(dataset)
    
    for iteration in range(n_iterations):
        current_metrics = []
        
        time_step, policy_state = collect_driver.run(time_step, policy_state)
        trajectories, buffer_info = next(iterator)
        
        train_loss = agent.train(trajectories)
        all_train_loss.append(train_loss.loss.numpy())

        for i in range(len(train_metrics)):
            current_metrics.append(train_metrics[i].result().numpy())
            
        all_metrics.append(current_metrics)
        
        if iteration % 500 == 0:
            print("\nIteration: {}, loss:{:.2f}".format(iteration, train_loss.loss.numpy()))
            
            for i in range(len(train_metrics)):
                print('{}: {}'.format(train_metrics[i].name, train_metrics[i].result().numpy()))

# %%
train_agent(150000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: calling foldr_v2 (from tensorflow.python.ops.functional_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.foldr(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.foldr(fn, elems))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: calling foldr_v2 (from tensorflow.python.ops.functional_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.foldr(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.foldr(fn, elems))
# Iteration: 0, loss:0.08
# AverageReturn: -0.30000001192092896
# AverageEpisodeLength: 1.0
#
# Iteration: 500, loss:0.02
# AverageReturn: -0.3699999749660492
# AverageEpisodeLength: 2.0999999046325684
#
# Iteration: 1000, loss:0.03
# AverageReturn: -0.7299999594688416
# AverageEpisodeLength: 3.299999952316284
#
# Iteration: 1500, loss:0.01
# AverageReturn: -0.44999998807907104
# AverageEpisodeLength: 1.5
#
# Iteration: 2000, loss:0.02
# AverageReturn: -0.4399999976158142
# AverageEpisodeLength: 1.899999976158142
#
# Iteration: 2500, loss:0.01
# AverageReturn: -0.4399999976158142
# AverageEpisodeLength: 1.899999976158142
#
# Iteration: 3000, loss:0.01
# AverageReturn: -0.6000000238418579
# AverageEpisodeLength: 2.0
#
# Iteration: 3500, loss:0.01
# AverageReturn: -0.23000001907348633
# AverageEpisodeLength: 1.2000000476837158
#
# Iteration: 4000, loss:0.02
# AverageReturn: -0.4000000059604645
# AverageEpisodeLength: 2.200000047683716
#
# Iteration: 4500, loss:0.02
# AverageReturn: -0.2800000309944153
# AverageEpisodeLength: 1.7999999523162842
#
# Iteration: 5000, loss:0.01
# AverageReturn: -0.30000001192092896
# AverageEpisodeLength: 2.299999952316284
#
# Iteration: 5500, loss:0.01
# AverageReturn: -0.33000001311302185
# AverageEpisodeLength: 2.4000000953674316
#
# Iteration: 6000, loss:0.02
# AverageReturn: -0.25999999046325684
# AverageEpisodeLength: 1.2999999523162842
#
# Iteration: 6500, loss:0.02
# AverageReturn: -0.3800000250339508
# AverageEpisodeLength: 1.7000000476837158
#
# Iteration: 7000, loss:0.01
# AverageReturn: -0.5800000429153442
# AverageEpisodeLength: 4.099999904632568
#
# Iteration: 7500, loss:0.02
# AverageReturn: -0.37000003457069397
# AverageEpisodeLength: 2.0999999046325684
#
# Iteration: 8000, loss:0.03
# AverageReturn: -0.5300000309944153
# AverageEpisodeLength: 2.200000047683716
#
# Iteration: 8500, loss:0.03
# AverageReturn: -0.33000001311302185
# AverageEpisodeLength: 2.4000000953674316
#
# Iteration: 9000, loss:0.03
# AverageReturn: -0.1900000274181366
# AverageEpisodeLength: 2.799999952316284
#
# Iteration: 9500, loss:0.02
# AverageReturn: -0.42000001668930054
# AverageEpisodeLength: 1.399999976158142
#
# Iteration: 10000, loss:0.04
# AverageReturn: -0.5200000405311584
# AverageEpisodeLength: 2.5999999046325684
#
# Iteration: 10500, loss:0.03
# AverageReturn: -0.35999998450279236
# AverageEpisodeLength: 1.2000000476837158
#
# Iteration: 11000, loss:0.03
# AverageReturn: 0.6399999856948853
# AverageEpisodeLength: 2.5999999046325684
#
# Iteration: 11500, loss:0.04
# AverageReturn: -0.320000022649765
# AverageEpisodeLength: 4.099999904632568
#
# Iteration: 12000, loss:0.05
# AverageReturn: -0.3699999749660492
# AverageEpisodeLength: 3.4000000953674316
#
# Iteration: 12500, loss:0.04
# AverageReturn: -0.4599999785423279
# AverageEpisodeLength: 3.700000047683716
#
# Iteration: 13000, loss:0.04
# AverageReturn: -0.5099999904632568
# AverageEpisodeLength: 1.7000000476837158
#
# Iteration: 13500, loss:0.04
# AverageReturn: -0.07999996840953827
# AverageEpisodeLength: 4.599999904632568
#
# Iteration: 14000, loss:0.07
# AverageReturn: -0.6399999856948853
# AverageEpisodeLength: 4.300000190734863
#
# Iteration: 14500, loss:0.05
# AverageReturn: -0.36000004410743713
# AverageEpisodeLength: 2.5
#
# Iteration: 15000, loss:0.05
# AverageReturn: -0.39000001549720764
# AverageEpisodeLength: 1.2999999523162842
#
# Iteration: 15500, loss:0.06
# AverageReturn: -0.4100000262260437
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 16000, loss:0.07
# AverageReturn: -0.42000001668930054
# AverageEpisodeLength: 1.399999976158142
#
# Iteration: 16500, loss:0.07
# AverageReturn: -0.3999999463558197
# AverageEpisodeLength: 3.5
#
# Iteration: 17000, loss:0.08
# AverageReturn: -0.2500000298023224
# AverageEpisodeLength: 4.300000190734863
#
# Iteration: 17500, loss:0.06
# AverageReturn: -0.36000004410743713
# AverageEpisodeLength: 2.5
#
# Iteration: 18000, loss:0.09
# AverageReturn: -0.4500000476837158
# AverageEpisodeLength: 2.799999952316284
#
# Iteration: 18500, loss:0.08
# AverageReturn: -0.35999998450279236
# AverageEpisodeLength: 5.099999904632568
#
# Iteration: 19000, loss:0.08
# AverageReturn: -0.27000004053115845
# AverageEpisodeLength: 3.5
#
# Iteration: 19500, loss:0.10
# AverageReturn: -0.33000001311302185
# AverageEpisodeLength: 2.4000000953674316
#
# Iteration: 20000, loss:0.09
# AverageReturn: -0.5100000500679016
# AverageEpisodeLength: 1.7000000476837158
#
# Iteration: 20500, loss:0.12
# AverageReturn: -0.440000057220459
# AverageEpisodeLength: 4.5
#
# Iteration: 21000, loss:0.08
# AverageReturn: 0.5799999833106995
# AverageEpisodeLength: 4.099999904632568
#
# Iteration: 21500, loss:0.11
# AverageReturn: 0.5999999642372131
# AverageEpisodeLength: 3.5999999046325684
#
# Iteration: 22000, loss:0.10
# AverageReturn: -0.36000004410743713
# AverageEpisodeLength: 2.5
#
# Iteration: 22500, loss:0.12
# AverageReturn: -0.30000001192092896
# AverageEpisodeLength: 2.299999952316284
#
# Iteration: 23000, loss:0.13
# AverageReturn: -0.24000000953674316
# AverageEpisodeLength: 2.0999999046325684
#
# Iteration: 23500, loss:0.11
# AverageReturn: 0.4500000476837158
# AverageEpisodeLength: 5.400000095367432
#
# Iteration: 24000, loss:0.16
# AverageReturn: 1.5199999809265137
# AverageEpisodeLength: 5.699999809265137
#
# Iteration: 24500, loss:0.16
# AverageReturn: 0.7699999213218689
# AverageEpisodeLength: 3.9000000953674316
#
# Iteration: 25000, loss:0.16
# AverageReturn: -0.39000004529953003
# AverageEpisodeLength: 2.5999999046325684
#
# Iteration: 25500, loss:0.12
# AverageReturn: -0.320000022649765
# AverageEpisodeLength: 2.799999952316284
#
# Iteration: 26000, loss:0.39
# AverageReturn: 0.23999996483325958
# AverageEpisodeLength: 6.099999904632568
#
# Iteration: 26500, loss:0.15
# AverageReturn: 0.2600000500679016
# AverageEpisodeLength: 4.300000190734863
#
# Iteration: 27000, loss:0.16
# AverageReturn: -1.0200002193450928
# AverageEpisodeLength: 6.0
#
# Iteration: 27500, loss:0.20
# AverageReturn: -0.14000003039836884
# AverageEpisodeLength: 2.200000047683716
#
# Iteration: 28000, loss:0.30
# AverageReturn: -0.010000228881835938
# AverageEpisodeLength: 6.5
#
# Iteration: 28500, loss:0.26
# AverageReturn: 0.5199999809265137
# AverageEpisodeLength: 6.900000095367432
#
# Iteration: 29000, loss:0.21
# AverageReturn: -0.9600003361701965
# AverageEpisodeLength: 7.099999904632568
#
# Iteration: 29500, loss:0.20
# AverageReturn: 1.4900000095367432
# AverageEpisodeLength: 5.800000190734863
#
# Iteration: 30000, loss:0.39
# AverageReturn: 0.7299999594688416
# AverageEpisodeLength: 3.5999999046325684
#
# Iteration: 30500, loss:0.19
# AverageReturn: 0.3699999749660492
# AverageEpisodeLength: 7.400000095367432
#
# Iteration: 31000, loss:0.26
# AverageReturn: 0.35999998450279236
# AverageEpisodeLength: 7.0
#
# Iteration: 31500, loss:0.30
# AverageReturn: -0.24000000953674316
# AverageEpisodeLength: 6.0
#
# Iteration: 32000, loss:0.50
# AverageReturn: 0.1499999463558197
# AverageEpisodeLength: 5.099999904632568
#
# Iteration: 32500, loss:0.33
# AverageReturn: 0.9899999499320984
# AverageEpisodeLength: 4.900000095367432
#
# Iteration: 33000, loss:0.38
# AverageReturn: -1.0400006771087646
# AverageEpisodeLength: 12.100000381469727
#
# Iteration: 33500, loss:0.37
# AverageReturn: 2.0999999046325684
# AverageEpisodeLength: 8.5
#
# Iteration: 34000, loss:1.02
# AverageReturn: 0.6499999761581421
# AverageEpisodeLength: 5.599999904632568
#
# Iteration: 34500, loss:0.53
# AverageReturn: 1.119999885559082
# AverageEpisodeLength: 4.900000095367432
#
# Iteration: 35000, loss:0.59
# AverageReturn: 1.0899999141693115
# AverageEpisodeLength: 6.300000190734863
#
# Iteration: 35500, loss:0.46
# AverageReturn: 0.6200000047683716
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 36000, loss:0.79
# AverageReturn: 3.0099997520446777
# AverageEpisodeLength: 10.199999809265137
#
# Iteration: 36500, loss:0.74
# AverageReturn: -0.010000097565352917
# AverageEpisodeLength: 9.100000381469727
#
# Iteration: 37000, loss:0.63
# AverageReturn: 0.47999995946884155
# AverageEpisodeLength: 6.599999904632568
#
# Iteration: 37500, loss:0.71
# AverageReturn: 0.320000022649765
# AverageEpisodeLength: 8.0
#
# Iteration: 38000, loss:0.97
# AverageReturn: 1.869999647140503
# AverageEpisodeLength: 6.699999809265137
#
# Iteration: 38500, loss:0.65
# AverageReturn: 2.119999885559082
# AverageEpisodeLength: 5.0
#
# Iteration: 39000, loss:0.66
# AverageReturn: -0.3300003111362457
# AverageEpisodeLength: 10.600000381469727
#
# Iteration: 39500, loss:0.66
# AverageReturn: 0.8700000047683716
# AverageEpisodeLength: 5.300000190734863
#
# Iteration: 40000, loss:0.91
# AverageReturn: 3.1599998474121094
# AverageEpisodeLength: 11.0
#
# Iteration: 40500, loss:0.67
# AverageReturn: 2.7800002098083496
# AverageEpisodeLength: 8.399999618530273
#
# Iteration: 41000, loss:0.79
# AverageReturn: 4.529999732971191
# AverageEpisodeLength: 10.300000190734863
#
# Iteration: 41500, loss:0.85
# AverageReturn: 3.879999876022339
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 42000, loss:0.74
# AverageReturn: 4.099999904632568
# AverageEpisodeLength: 9.600000381469727
#
# Iteration: 42500, loss:0.74
# AverageReturn: 2.4599997997283936
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 43000, loss:0.89
# AverageReturn: 2.930000066757202
# AverageEpisodeLength: 7.900000095367432
#
# Iteration: 43500, loss:0.55
# AverageReturn: 4.5
# AverageEpisodeLength: 7.400000095367432
#
# Iteration: 44000, loss:0.90
# AverageReturn: 4.099999904632568
# AverageEpisodeLength: 7.0
#
# Iteration: 44500, loss:0.57
# AverageReturn: 5.310000419616699
# AverageEpisodeLength: 9.0
#
# Iteration: 45000, loss:0.93
# AverageReturn: 3.059999465942383
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 45500, loss:0.87
# AverageReturn: 1.989999532699585
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 46000, loss:0.63
# AverageReturn: 5.700000286102295
# AverageEpisodeLength: 9.0
#
# Iteration: 46500, loss:0.86
# AverageReturn: 2.559999942779541
# AverageEpisodeLength: 10.0
#
# Iteration: 47000, loss:0.76
# AverageReturn: 7.489999294281006
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 47500, loss:0.70
# AverageReturn: 4.460000038146973
# AverageEpisodeLength: 5.800000190734863
#
# Iteration: 48000, loss:0.87
# AverageReturn: 7.25
# AverageEpisodeLength: 10.699999809265137
#
# Iteration: 48500, loss:0.76
# AverageReturn: 2.259999990463257
# AverageEpisodeLength: 5.400000095367432
#
# Iteration: 49000, loss:0.91
# AverageReturn: 5.099999904632568
# AverageEpisodeLength: 11.0
#
# Iteration: 49500, loss:0.64
# AverageReturn: 5.429999828338623
# AverageEpisodeLength: 7.300000190734863
#
# Iteration: 50000, loss:0.55
# AverageReturn: 7.5799994468688965
# AverageEpisodeLength: 8.300000190734863
#
# Iteration: 50500, loss:0.48
# AverageReturn: 6.619999885559082
# AverageEpisodeLength: 8.5
#
# Iteration: 51000, loss:0.58
# AverageReturn: 8.989999771118164
# AverageEpisodeLength: 7.900000095367432
#
# Iteration: 51500, loss:0.71
# AverageReturn: 6.689999580383301
# AverageEpisodeLength: 10.0
#
# Iteration: 52000, loss:0.93
# AverageReturn: 7.609999656677246
# AverageEpisodeLength: 10.800000190734863
#
# Iteration: 52500, loss:0.91
# AverageReturn: 3.9900002479553223
# AverageEpisodeLength: 9.100000381469727
#
# Iteration: 53000, loss:1.01
# AverageReturn: 8.559999465942383
# AverageEpisodeLength: 10.199999809265137
#
# Iteration: 53500, loss:0.49
# AverageReturn: 5.939999580383301
# AverageEpisodeLength: 8.199999809265137
#
# Iteration: 54000, loss:0.84
# AverageReturn: 7.7300004959106445
# AverageEpisodeLength: 9.100000381469727
#
# Iteration: 54500, loss:0.67
# AverageReturn: 6.679999351501465
# AverageEpisodeLength: 8.300000190734863
#
# Iteration: 55000, loss:0.53
# AverageReturn: 5.509999752044678
# AverageEpisodeLength: 6.599999904632568
#
# Iteration: 55500, loss:0.61
# AverageReturn: 9.960000038146973
# AverageEpisodeLength: 9.399999618530273
#
# Iteration: 56000, loss:0.87
# AverageReturn: 7.5199995040893555
# AverageEpisodeLength: 8.5
#
# Iteration: 56500, loss:0.92
# AverageReturn: 9.050000190734863
# AverageEpisodeLength: 9.0
#
# Iteration: 57000, loss:0.56
# AverageReturn: 10.180000305175781
# AverageEpisodeLength: 9.100000381469727
#
# Iteration: 57500, loss:0.94
# AverageReturn: 8.84000015258789
# AverageEpisodeLength: 9.699999809265137
#
# Iteration: 58000, loss:0.54
# AverageReturn: 8.999999046325684
# AverageEpisodeLength: 8.300000190734863
#
# Iteration: 58500, loss:0.83
# AverageReturn: 8.079999923706055
# AverageEpisodeLength: 7.5
#
# Iteration: 59000, loss:0.69
# AverageReturn: 10.519999504089355
# AverageEpisodeLength: 9.699999809265137
#
# Iteration: 59500, loss:0.55
# AverageReturn: 7.869999885559082
# AverageEpisodeLength: 8.199999809265137
#
# Iteration: 60000, loss:0.52
# AverageReturn: 10.380000114440918
# AverageEpisodeLength: 9.300000190734863
#
# Iteration: 60500, loss:0.52
# AverageReturn: 10.670000076293945
# AverageEpisodeLength: 10.5
#
# Iteration: 61000, loss:0.64
# AverageReturn: 10.469999313354492
# AverageEpisodeLength: 10.300000190734863
#
# Iteration: 61500, loss:0.65
# AverageReturn: 11.630000114440918
# AverageEpisodeLength: 11.600000381469727
#
# Iteration: 62000, loss:0.36
# AverageReturn: 11.660000801086426
# AverageEpisodeLength: 11.5
#
# Iteration: 62500, loss:0.63
# AverageReturn: -12.580024719238281
# AverageEpisodeLength: 81.5999984741211
#
# Iteration: 63000, loss:0.74
# AverageReturn: 10.619999885559082
# AverageEpisodeLength: 16.700000762939453
#
# Iteration: 63500, loss:0.72
# AverageReturn: 11.839999198913574
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 64000, loss:0.60
# AverageReturn: 1.7700001001358032
# AverageEpisodeLength: 37.599998474121094
#
# Iteration: 64500, loss:0.75
# AverageReturn: 11.440000534057617
# AverageEpisodeLength: 9.199999809265137
#
# Iteration: 65000, loss:0.63
# AverageReturn: 10.219999313354492
# AverageEpisodeLength: 9.399999618530273
#
# Iteration: 65500, loss:0.41
# AverageReturn: 9.030000686645508
# AverageEpisodeLength: 8.199999809265137
#
# Iteration: 66000, loss:0.95
# AverageReturn: 4.520005226135254
# AverageEpisodeLength: 26.700000762939453
#
# Iteration: 66500, loss:0.55
# AverageReturn: 10.15999984741211
# AverageEpisodeLength: 10.899999618530273
#
# Iteration: 67000, loss:0.28
# AverageReturn: 9.899999618530273
# AverageEpisodeLength: 16.5
#
# Iteration: 67500, loss:0.58
# AverageReturn: 11.519999504089355
# AverageEpisodeLength: 11.100000381469727
#
# Iteration: 68000, loss:0.50
# AverageReturn: 8.139999389648438
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 68500, loss:0.77
# AverageReturn: 11.420000076293945
# AverageEpisodeLength: 11.0
#
# Iteration: 69000, loss:0.73
# AverageReturn: 10.390000343322754
# AverageEpisodeLength: 8.399999618530273
#
# Iteration: 69500, loss:0.58
# AverageReturn: 11.390000343322754
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 70000, loss:0.74
# AverageReturn: 11.120000839233398
# AverageEpisodeLength: 10.699999809265137
#
# Iteration: 70500, loss:0.46
# AverageReturn: 11.589999198913574
# AverageEpisodeLength: 10.0
#
# Iteration: 71000, loss:1.15
# AverageReturn: 11.469999313354492
# AverageEpisodeLength: 10.399999618530273
#
# Iteration: 71500, loss:0.58
# AverageReturn: 11.110000610351562
# AverageEpisodeLength: 12.899999618530273
#
# Iteration: 72000, loss:0.55
# AverageReturn: 10.25999927520752
# AverageEpisodeLength: 11.0
#
# Iteration: 72500, loss:0.64
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 73000, loss:0.89
# AverageReturn: 10.360000610351562
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 73500, loss:0.63
# AverageReturn: 11.440000534057617
# AverageEpisodeLength: 9.199999809265137
#
# Iteration: 74000, loss:0.55
# AverageReturn: 8.080000877380371
# AverageEpisodeLength: 17.399999618530273
#
# Iteration: 74500, loss:0.89
# AverageReturn: -83.54754638671875
# AverageEpisodeLength: 320.70001220703125
#
# Iteration: 75000, loss:0.41
# AverageReturn: 11.530000686645508
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 75500, loss:0.65
# AverageReturn: 10.699999809265137
# AverageEpisodeLength: 16.0
#
# Iteration: 76000, loss:0.52
# AverageReturn: 11.839999198913574
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 76500, loss:0.57
# AverageReturn: 11.399999618530273
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 77000, loss:0.80
# AverageReturn: 10.559999465942383
# AverageEpisodeLength: 13.899999618530273
#
# Iteration: 77500, loss:0.87
# AverageReturn: 11.519999504089355
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 78000, loss:0.53
# AverageReturn: 11.630000114440918
# AverageEpisodeLength: 11.600000381469727
#
# Iteration: 78500, loss:0.55
# AverageReturn: 11.569999694824219
# AverageEpisodeLength: 14.399999618530273
#
# Iteration: 79000, loss:0.72
# AverageReturn: 11.619999885559082
# AverageEpisodeLength: 13.800000190734863
#
# Iteration: 79500, loss:0.52
# AverageReturn: 11.5
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 80000, loss:0.78
# AverageReturn: 11.5600004196167
# AverageEpisodeLength: 14.0
#
# Iteration: 80500, loss:0.54
# AverageReturn: 10.889999389648438
# AverageEpisodeLength: 11.5
#
# Iteration: 81000, loss:0.65
# AverageReturn: 9.459999084472656
# AverageEpisodeLength: 15.399999618530273
#
# Iteration: 81500, loss:0.36
# AverageReturn: 11.839999198913574
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 82000, loss:0.34
# AverageReturn: 11.719999313354492
# AverageEpisodeLength: 12.600000381469727
#
# Iteration: 82500, loss:0.61
# AverageReturn: 10.480000495910645
# AverageEpisodeLength: 10.699999809265137
#
# Iteration: 83000, loss:0.73
# AverageReturn: 11.300000190734863
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 83500, loss:0.37
# AverageReturn: 10.910000801086426
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 84000, loss:0.37
# AverageReturn: 9.539999008178711
# AverageEpisodeLength: 17.700000762939453
#
# Iteration: 84500, loss:0.56
# AverageReturn: 9.630000114440918
# AverageEpisodeLength: 20.0
#
# Iteration: 85000, loss:0.69
# AverageReturn: 9.389999389648438
# AverageEpisodeLength: 16.5
#
# Iteration: 85500, loss:0.29
# AverageReturn: 10.479999542236328
# AverageEpisodeLength: 12.0
#
# Iteration: 86000, loss:0.91
# AverageReturn: 11.420000076293945
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 86500, loss:0.48
# AverageReturn: 9.90999984741211
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 87000, loss:0.50
# AverageReturn: 9.5600004196167
# AverageEpisodeLength: 15.5
#
# Iteration: 87500, loss:0.54
# AverageReturn: 10.100000381469727
# AverageEpisodeLength: 18.0
#
# Iteration: 88000, loss:0.53
# AverageReturn: 10.699999809265137
# AverageEpisodeLength: 16.0
#
# Iteration: 88500, loss:0.35
# AverageReturn: 9.119999885559082
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 89000, loss:0.62
# AverageReturn: 2.5899860858917236
# AverageEpisodeLength: 42.599998474121094
#
# Iteration: 89500, loss:0.51
# AverageReturn: 10.639999389648438
# AverageEpisodeLength: 11.899999618530273
#
# Iteration: 90000, loss:0.53
# AverageReturn: 7.440004825592041
# AverageEpisodeLength: 27.299999237060547
#
# Iteration: 90500, loss:0.69
# AverageReturn: 10.380000114440918
# AverageEpisodeLength: 9.300000190734863
#
# Iteration: 91000, loss:0.85
# AverageReturn: 9.819999694824219
# AverageEpisodeLength: 11.600000381469727
#
# Iteration: 91500, loss:0.45
# AverageReturn: 9.239999771118164
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 92000, loss:0.90
# AverageReturn: 10.440000534057617
# AverageEpisodeLength: 10.399999618530273
#
# Iteration: 92500, loss:0.59
# AverageReturn: 11.359999656677246
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 93000, loss:0.62
# AverageReturn: 9.980000495910645
# AverageEpisodeLength: 10.199999809265137
#
# Iteration: 93500, loss:0.52
# AverageReturn: 11.410000801086426
# AverageEpisodeLength: 9.300000190734863
#
# Iteration: 94000, loss:0.64
# AverageReturn: 11.380000114440918
# AverageEpisodeLength: 10.699999809265137
#
# Iteration: 94500, loss:0.66
# AverageReturn: 0.47000694274902344
# AverageEpisodeLength: 40.20000076293945
#
# Iteration: 95000, loss:0.12
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 95500, loss:0.67
# AverageReturn: 11.40999984741211
# AverageEpisodeLength: 10.600000381469727
#
# Iteration: 96000, loss:0.56
# AverageReturn: 11.649999618530273
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 96500, loss:0.36
# AverageReturn: 12.010000228881836
# AverageEpisodeLength: 12.5
#
# Iteration: 97000, loss:0.82
# AverageReturn: 11.879999160766602
# AverageEpisodeLength: 12.5
#
# Iteration: 97500, loss:0.60
# AverageReturn: 11.960000991821289
# AverageEpisodeLength: 13.100000381469727
#
# Iteration: 98000, loss:0.24
# AverageReturn: 11.920000076293945
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 98500, loss:0.36
# AverageReturn: 11.290000915527344
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 99000, loss:0.44
# AverageReturn: 11.25
# AverageEpisodeLength: 12.899999618530273
#
# Iteration: 99500, loss:0.66
# AverageReturn: 11.989999771118164
# AverageEpisodeLength: 14.300000190734863
#
# Iteration: 100000, loss:0.60
# AverageReturn: 12.460000991821289
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 100500, loss:0.63
# AverageReturn: 10.5600004196167
# AverageEpisodeLength: 12.600000381469727
#
# Iteration: 101000, loss:0.77
# AverageReturn: 10.640000343322754
# AverageEpisodeLength: 11.899999618530273
#
# Iteration: 101500, loss:0.45
# AverageReturn: 11.899999618530273
# AverageEpisodeLength: 12.0
#
# Iteration: 102000, loss:0.38
# AverageReturn: 11.780000686645508
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 102500, loss:0.49
# AverageReturn: 12.029999732971191
# AverageEpisodeLength: 13.300000190734863
#
# Iteration: 103000, loss:0.36
# AverageReturn: 12.059999465942383
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 103500, loss:0.12
# AverageReturn: 11.949999809265137
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 104000, loss:0.29
# AverageReturn: 10.850000381469727
# AverageEpisodeLength: 12.5
#
# Iteration: 104500, loss:0.61
# AverageReturn: 11.90999984741211
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 105000, loss:0.36
# AverageReturn: 10.949999809265137
# AverageEpisodeLength: 14.300000190734863
#
# Iteration: 105500, loss:0.51
# AverageReturn: 12.010000228881836
# AverageEpisodeLength: 11.199999809265137
#
# Iteration: 106000, loss:0.39
# AverageReturn: 11.449999809265137
# AverageEpisodeLength: 13.5
#
# Iteration: 106500, loss:0.54
# AverageReturn: 12.25
# AverageEpisodeLength: 13.0
#
# Iteration: 107000, loss:0.54
# AverageReturn: 12.050000190734863
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 107500, loss:0.52
# AverageReturn: 11.90999984741211
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 108000, loss:0.42
# AverageReturn: 11.980000495910645
# AverageEpisodeLength: 12.600000381469727
#
# Iteration: 108500, loss:0.77
# AverageReturn: 12.350000381469727
# AverageEpisodeLength: 14.399999618530273
#
# Iteration: 109000, loss:0.78
# AverageReturn: 11.380000114440918
# AverageEpisodeLength: 12.899999618530273
#
# Iteration: 109500, loss:0.29
# AverageReturn: 12.540000915527344
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 110000, loss:0.58
# AverageReturn: 12.480000495910645
# AverageEpisodeLength: 14.399999618530273
#
# Iteration: 110500, loss:0.28
# AverageReturn: 12.480000495910645
# AverageEpisodeLength: 14.399999618530273
#
# Iteration: 111000, loss:0.39
# AverageReturn: 11.3100004196167
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 111500, loss:0.47
# AverageReturn: 11.230000495910645
# AverageEpisodeLength: 13.399999618530273
#
# Iteration: 112000, loss:0.29
# AverageReturn: 12.210000038146973
# AverageEpisodeLength: 14.0
#
# Iteration: 112500, loss:0.52
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 113000, loss:0.44
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 113500, loss:0.58
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 114000, loss:0.30
# AverageReturn: 12.539999961853027
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 114500, loss:0.72
# AverageReturn: 12.460000991821289
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 115000, loss:0.40
# AverageReturn: 12.239999771118164
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 115500, loss:0.74
# AverageReturn: 10.969999313354492
# AverageEpisodeLength: 10.800000190734863
#
# Iteration: 116000, loss:0.32
# AverageReturn: 12.079999923706055
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 116500, loss:0.63
# AverageReturn: 11.699999809265137
# AverageEpisodeLength: 14.399999618530273
#
# Iteration: 117000, loss:0.59
# AverageReturn: 4.2200026512146
# AverageEpisodeLength: 23.399999618530273
#
# Iteration: 117500, loss:0.59
# AverageReturn: 10.149999618530273
# AverageEpisodeLength: 14.399999618530273
#
# Iteration: 118000, loss:0.66
# AverageReturn: 11.6899995803833
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 118500, loss:0.44
# AverageReturn: 12.079999923706055
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 119000, loss:0.53
# AverageReturn: 12.059999465942383
# AverageEpisodeLength: 10.600000381469727
#
# Iteration: 119500, loss:0.39
# AverageReturn: 9.319998741149902
# AverageEpisodeLength: 20.600000381469727
#
# Iteration: 120000, loss:0.62
# AverageReturn: 9.380002975463867
# AverageEpisodeLength: 21.700000762939453
#
# Iteration: 120500, loss:0.62
# AverageReturn: 9.929999351501465
# AverageEpisodeLength: 17.299999237060547
#
# Iteration: 121000, loss:0.37
# AverageReturn: 11.800000190734863
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 121500, loss:0.29
# AverageReturn: 10.989999771118164
# AverageEpisodeLength: 15.899999618530273
#
# Iteration: 122000, loss:0.38
# AverageReturn: 11.699999809265137
# AverageEpisodeLength: 13.100000381469727
#
# Iteration: 122500, loss:0.64
# AverageReturn: 12.179999351501465
# AverageEpisodeLength: 11.5
#
# Iteration: 123000, loss:0.45
# AverageReturn: 11.129999160766602
# AverageEpisodeLength: 10.699999809265137
#
# Iteration: 123500, loss:0.38
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 124000, loss:0.22
# AverageReturn: 11.100000381469727
# AverageEpisodeLength: 10.800000190734863
#
# Iteration: 124500, loss:0.41
# AverageReturn: 12.219999313354492
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 125000, loss:0.39
# AverageReturn: 12.170000076293945
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 125500, loss:0.55
# AverageReturn: 12.170000076293945
# AverageEpisodeLength: 11.100000381469727
#
# Iteration: 126000, loss:0.59
# AverageReturn: 12.329999923706055
# AverageEpisodeLength: 12.300000190734863
#
# Iteration: 126500, loss:0.74
# AverageReturn: 10.889999389648438
# AverageEpisodeLength: 10.199999809265137
#
# Iteration: 127000, loss:0.29
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 127500, loss:0.38
# AverageReturn: 9.619999885559082
# AverageEpisodeLength: 9.699999809265137
#
# Iteration: 128000, loss:0.52
# AverageReturn: 12.140000343322754
# AverageEpisodeLength: 11.199999809265137
#
# Iteration: 128500, loss:0.43
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 129000, loss:0.28
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 129500, loss:0.45
# AverageReturn: 11.030000686645508
# AverageEpisodeLength: 10.600000381469727
#
# Iteration: 130000, loss:0.30
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 130500, loss:0.41
# AverageReturn: 12.480000495910645
# AverageEpisodeLength: 13.100000381469727
#
# Iteration: 131000, loss:0.54
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 131500, loss:0.42
# AverageReturn: 12.5600004196167
# AverageEpisodeLength: 13.699999809265137
#
# Iteration: 132000, loss:0.22
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 132500, loss:0.12
# AverageReturn: 9.850000381469727
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 133000, loss:0.28
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 133500, loss:0.73
# AverageReturn: 12.070000648498535
# AverageEpisodeLength: 11.0
#
# Iteration: 134000, loss:0.72
# AverageReturn: 12.129999160766602
# AverageEpisodeLength: 10.800000190734863
#
# Iteration: 134500, loss:0.39
# AverageReturn: 12.420000076293945
# AverageEpisodeLength: 13.300000190734863
#
# Iteration: 135000, loss:0.50
# AverageReturn: 12.260000228881836
# AverageEpisodeLength: 12.100000381469727
#
# Iteration: 135500, loss:0.28
# AverageReturn: 11.130000114440918
# AverageEpisodeLength: 12.0
#
# Iteration: 136000, loss:0.21
# AverageReturn: 12.339999198913574
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 136500, loss:0.67
# AverageReturn: 12.539999961853027
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 137000, loss:0.38
# AverageReturn: 11.789999961853027
# AverageEpisodeLength: 16.700000762939453
#
# Iteration: 137500, loss:0.20
# AverageReturn: 12.540000915527344
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 138000, loss:0.37
# AverageReturn: 11.569999694824219
# AverageEpisodeLength: 14.0
#
# Iteration: 138500, loss:0.44
# AverageReturn: 12.540000915527344
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 139000, loss:0.36
# AverageReturn: 11.539999961853027
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 139500, loss:0.43
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 140000, loss:0.30
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 140500, loss:0.28
# AverageReturn: 12.510000228881836
# AverageEpisodeLength: 14.300000190734863
#
# Iteration: 141000, loss:0.13
# AverageReturn: 11.09000015258789
# AverageEpisodeLength: 15.600000381469727
#
# Iteration: 141500, loss:0.45
# AverageReturn: 11.30000114440918
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 142000, loss:0.52
# AverageReturn: 12.460000991821289
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 142500, loss:0.47
# AverageReturn: 12.540000915527344
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 143000, loss:0.30
# AverageReturn: 12.570000648498535
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 143500, loss:0.49
# AverageReturn: 10.949999809265137
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 144000, loss:0.50
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 144500, loss:0.39
# AverageReturn: 10.260000228881836
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 145000, loss:0.44
# AverageReturn: 12.239999771118164
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 145500, loss:0.39
# AverageReturn: 10.819999694824219
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 146000, loss:0.39
# AverageReturn: 11.460000991821289
# AverageEpisodeLength: 13.5
#
# Iteration: 146500, loss:0.68
# AverageReturn: 9.670000076293945
# AverageEpisodeLength: 11.699999809265137
#
# Iteration: 147000, loss:0.37
# AverageReturn: 12.420000076293945
# AverageEpisodeLength: 14.600000381469727
#
# Iteration: 147500, loss:0.29
# AverageReturn: 12.200000762939453
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 148000, loss:0.21
# AverageReturn: 12.380000114440918
# AverageEpisodeLength: 13.0
#
# Iteration: 148500, loss:0.21
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 149000, loss:0.20
# AverageReturn: 12.079999923706055
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 149500, loss:0.39
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0

# %%
avg_return_trained = column(all_metrics,0)
avg_ep_trained = column(all_metrics,1)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,15))

axs[0].plot(range(len(avg_return_trained)), avg_return_trained)
axs[0].set_title('Average Return')

axs[1].plot(range(len(avg_ep_trained)), avg_ep_trained, 'tab:orange')
axs[1].set_title('Average Episode Length')

for ax in axs.flat:
    ax.set(xlabel='Number of Iterations', ylabel='Metric Value')

# %% [markdown]
# ### Evaluate

# %%
def compute_avg_return(environment, policy, num_episodes=10):

    total_return = 0.0
    
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        
        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
        
        total_return += episode_return

    avg_return = total_return / num_episodes
    
    return avg_return.numpy()[0]

# %%
# Reset the train step
agent.train_step_counter.assign(0)

#reset eval environment
eval_env.reset()

# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, agent.policy, 5)

# %%
avg_return
# Out:
# 12.2

# %% [markdown]
# ### Visualize Episode

# %%
def observation_viz(observation):
    numpy_obs = observation.numpy()[0]
    string_obs = np.array(np.reshape(numpy_obs, (-1, 6)), dtype=np.unicode_)
    if string_obs[5][5] != "1":
      string_obs[5][5] = "❌"
    string_obs = np.where(string_obs=="1","🐕", string_obs) 
    string_obs = np.where(string_obs=="2","🤖", string_obs)
    string_obs = np.where(string_obs=="3","🦴", string_obs)
    string_obs = np.where(string_obs=="0","⬚", string_obs)
    observe_2d = pd.DataFrame(string_obs)
    observe_2d.columns = [''] * len(observe_2d.columns)
    observe_2d = observe_2d.to_string(index=False)
    print("\n{}\n".format(observe_2d))

# %%
def compute_viz(environment, policy, num_episodes=20):

    total_return = 0.0
    
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        step = 0
        print("Step: 0")
        observation_viz(time_step.observation)
        while not time_step.is_last():
            step += 1
            print("---\nStep: {}".format(step))
            action_step = policy.action(time_step)
            print("Action taken: {}".format(action_step.action))
            time_step = environment.step(action_step.action)
            observation_viz(time_step.observation)
            episode_return += time_step.reward
            print("Reward: {} \n".format(episode_return))
        
        total_return += episode_return

    avg_return = total_return / num_episodes
    
    return avg_return.numpy()[0]

# %%
# Reset the train step
agent.train_step_counter.assign(0)

#reset eval environment
eval_env.reset()

# Evaluate the agent's policy once before training.
avg_return = compute_viz(eval_env, agent.policy, 1)
# Out:
# Step: 0
#
#
#  🐕  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  🦴  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# ---
# Step: 1
# Action taken: [1]
#
#
#  ⬚  🐕  ⬚  ⬚  ⬚  🦴
#  🤖  🦴  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [-0.3]
#
# ---
# Step: 2
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  🐕  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [0.7]
#
# ---
# Step: 3
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  🐕  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [0.39999998]
#
# ---
# Step: 4
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🐕  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [1.4]
#
# ---
# Step: 5
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  🐕  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [1.0999999]
#
# ---
# Step: 6
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🐕  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [2.1]
#
# ---
# Step: 7
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  ⬚  ⬚  ⬚  ⬚
#  🦴  ⬚  🐕  🤖  ⬚  ❌
#
# Reward: [1.8]
#
# ---
# Step: 8
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  ⬚  ⬚  ⬚  ⬚
#  🦴  🐕  ⬚  🤖  ⬚  ❌
#
# Reward: [1.5]
#
# ---
# Step: 9
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  ⬚  ⬚  ⬚  ⬚
#  🐕  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [2.5]
#
# ---
# Step: 10
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  ⬚  ⬚  ⬚  🐕
#  ⬚  ⬚  ⬚  🤖  ⬚  ❌
#
# Reward: [2.2]
#
# ---
# Step: 11
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🤖  ⬚  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🤖  ⬚  🐕
#
# Reward: [12.2]

# %% [markdown]
# ### Saving/Loading the Agent

# %%
from datetime import datetime

# %%
folder_name = datetime.now().timestamp()
folder_name = "/content/saved_agents/"+str(folder_name)

# %% [markdown]
# #### Saving the agent

# %%
tf.saved_model.save(agent, folder_name)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/saved_agents/1608125988.317696/assets
# INFO:tensorflow:Assets written to: /content/saved_agents/1608125988.317696/assets

# %%
# !zip -r saved_agent.zip /content/saved_agents/1590937968.715281/
# Out:
# 	zip warning: name not matched: /content/saved_agents/1590937968.715281/
#
# zip error: Nothing to do! (try: zip -r saved_agent.zip . -i /content/saved_agents/1590937968.715281/)

# %% [markdown]
# #### Loading the agent
